# %% [markdown]
# <h1>Clustermarket Data Analysis</h1>

# %% [markdown]
# <h2>Dataset Cleanup</h2>

# %%
#Update File Path
clustermarket_file = 'Resources/Clustermarket Randomized Data 17OCT2023-27OCT2023.csv'
Lab_users_list = 'Resources/Laboratory_Users_List.csv'

# %%
#Import dependencies
import pandas as pd
from pathlib import Path
import sys
import matplotlib.pyplot as plt
import numpy as np
import os
import seaborn as sns
from matplotlib.colors import ListedColormap
from datetime import datetime as dt

# %%
#Reference file that we are analyzing
Clustermarket_Path = Path(clustermarket_file)
Clustermarket_RawData = pd.read_csv(Clustermarket_Path,encoding='latin-1')

Clustermarket_RawData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 581 entries, 0 to 580
# Data columns (total 40 columns):
#  #   Column                                                                Non-Null Count  Dtype
# ---  ------                                                                --------------  -----
#  0   Booking ID                                                            581 non-null    int64
#  1   Equipment ID                                                          581 non-null    int64
#  2   Equipment Name                                                        581 non-null    object
#  3   Room                                                                  581 non-null    object
#  4   Requester Organisation ID                                             581 non-null    int64
#  5   Requester Organisation Name                                           581 non-null    object
#  6   Requester Laboratory ID                                               581 non-null    int64
#  7   Requester Laboratory Name                                             581 non-null    object
#  8   Provider Organisation ID                                              581 non-null    int64
#  9   Provider Organisation Name                                            581 non-null    object
#  10  Provider Laboratory ID                                                581 non-null    int64
#  11  Provider Laboratory Name                                              581 non-null    object
#  12  Requester ID                                                          581 non-null    int64
#  13  Requester Name                                                        581 non-null    object
#  14  Requester Email                                                       581 non-null    object
#  15  Requester Sector                                                      581 non-null    object
#  16  Booking Type                                                          581 non-null    object
#  17  Booked by                                                             1 non-null      object
#  18  Add-ons                                                               0 non-null      float64
#  19  Cost                                                                  581 non-null    int64
#  20  Currency                                                              581 non-null    object
#  21  Status                                                                581 non-null    object
#  22  Booking Category                                                      581 non-null    object
#  23  Requested At                                                          581 non-null    object
#  24  Approved At                                                           0 non-null      float64
#  25  Booked At                                                             0 non-null      float64
#  26  Ordered At                                                            0 non-null      float64
#  27  Completed At                                                          581 non-null    object
#  28  Cancelled At                                                          0 non-null      float64
#  29  Declined At                                                           0 non-null      float64
#  30  Charging Type                                                         581 non-null    object
#  31  Start Time                                                            581 non-null    object
#  32  End Time                                                              581 non-null    object
#  33  Duration (minutes)                                                    581 non-null    int64
#  34  Actual Start Time                                                     0 non-null      float64
#  35  Actual End Time                                                       0 non-null      float64
#  36  Actual Duration (minutes)                                             0 non-null      float64
#  37  Requester Group Name                                                  0 non-null      float64
#  38  Notes                                                                 0 non-null      float64
#  39  Project Name, Project Supervisor, [...Funding Code, Funder, Amount];  0 non-null      float64
# dtypes: float64(12), int64(9), object(19)
# memory usage: 181.7+ KB

# %%
#Defining a formula that elimates rows with declined bookings
def filter_rows_by_variable(df, col, values):
    return df[~df[col].isin([values])]

#Remove declined bookings
Clustermarket_RawData = filter_rows_by_variable(Clustermarket_RawData,"Status","declined")

Clustermarket_RawData.head()
# Out:
#    Booking ID  Equipment ID                          Equipment Name   Room  \
# 0     7961782          1001                   BioSafety Class II A2  Lab 1
# 1     7961783          1001                   BioSafety Class II A2  Lab 1
# 2     7961832          2001  AquaMate 8100 UV-Vis Spectrophotometer  Lab 2
# 3     7961833          3001    Atomic Absorption Spectroscopy (AAS)  Lab 3
# 4     7961883          4001                          NovaSeq X Plus  Lab 4
#
#    Requester Organisation ID Requester Organisation Name  \
# 0                      12345             Biotech Company
# 1                      12345             Biotech Company
# 2                      12345             Biotech Company
# 3                      12345             Biotech Company
# 4                      12345             Biotech Company
#
#    Requester Laboratory ID Requester Laboratory Name  \
# 0                    14324                   R&D Lab
# 1                    14324                   R&D Lab
# 2                    14324                   R&D Lab
# 3                    14324                   R&D Lab
# 4                    14324                   R&D Lab
#
#    Provider Organisation ID Provider Organisation Name  ...  Charging Type  \
# 0                     12345            Biotech Company  ...       Per Hour
# 1                     12345            Biotech Company  ...       Per Hour
# 2                     12345            Biotech Company  ...       Per Hour
# 3                     12345            Biotech Company  ...       Per Hour
# 4                     12345            Biotech Company  ...       Per Hour
#
#       Start Time        End Time Duration (minutes) Actual Start Time  \
# 0  10/16/23 9:30  10/16/23 14:00                270               NaN
# 1  10/23/23 9:30  10/23/23 14:00                270               NaN
# 2  10/16/23 9:30  10/16/23 14:00                270               NaN
# 3  10/23/23 9:30  10/23/23 14:00                270               NaN
# 4  10/23/23 9:30  10/23/23 14:00                270               NaN
#
#   Actual End Time Actual Duration (minutes) Requester Group Name  Notes  \
# 0             NaN                       NaN                  NaN    NaN
# 1             NaN                       NaN                  NaN    NaN
# 2             NaN                       NaN                  NaN    NaN
# 3             NaN                       NaN                  NaN    NaN
# 4             NaN                       NaN                  NaN    NaN
#
#    Project Name, Project Supervisor, [...Funding Code, Funder, Amount];
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 40 columns]

# %%
#Clean up Dataset
Clustermarket_Data = pd.DataFrame(Clustermarket_RawData,columns=[
    'Equipment ID',
    'Status',
    'Equipment Name',
    'Room',
    'Requester Name',
    'Booking Category',
    'Requested At',
    'Start Time',
    'Duration (minutes)',
    'Requester Group Name',
    'Notes'])

#Convert dataset to timeframe format
Clustermarket_Data["Requested At"]= pd.to_datetime(Clustermarket_Data["Requested At"], yearfirst=True, infer_datetime_format = True)
Clustermarket_Data["Requested At"]= Clustermarket_Data["Requested At"].dt.strftime('%Y/%m/%d')
Clustermarket_Data["Start Time"]= pd.to_datetime(Clustermarket_Data["Start Time"], yearfirst=True, infer_datetime_format = True)
Clustermarket_Data["Start Time"]= Clustermarket_Data["Start Time"].dt.strftime('%Y/%m/%d')

#Rename "Breakdown", "Repair" & "Other" as Unplanned
Clustermarket_Data['Booking Category'] = Clustermarket_Data['Booking Category'].replace(['Breakdown',
                                                                                         'Repair',
                                                                                         'Other'],
                                                                                        'Unplanned')

#Rename "Preventative Maintenance", "Cleaning" & "Calibration" as Periodic Maintenance
Clustermarket_Data['Booking Category'] = Clustermarket_Data['Booking Category'].replace(['Preventative Maintenance',
                                                                                         'Calibration',
                                                                                         'Cleaning'],
                                                                                        'Periodic Maintenance')



Clustermarket_Data.head()
# Out:
# C:\Users\ljlle\AppData\Local\Temp\ipykernel_3428\59281533.py:16: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   Clustermarket_Data["Requested At"]= pd.to_datetime(Clustermarket_Data["Requested At"], yearfirst=True, infer_datetime_format = True)
# C:\Users\ljlle\AppData\Local\Temp\ipykernel_3428\59281533.py:18: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   Clustermarket_Data["Start Time"]= pd.to_datetime(Clustermarket_Data["Start Time"], yearfirst=True, infer_datetime_format = True)
# C:\Users\ljlle\AppData\Local\Temp\ipykernel_3428\59281533.py:18: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   Clustermarket_Data["Start Time"]= pd.to_datetime(Clustermarket_Data["Start Time"], yearfirst=True, infer_datetime_format = True)
#    Equipment ID     Status                          Equipment Name   Room  \
# 0          1001  completed                   BioSafety Class II A2  Lab 1
# 1          1001  completed                   BioSafety Class II A2  Lab 1
# 2          2001  completed  AquaMate 8100 UV-Vis Spectrophotometer  Lab 2
# 3          3001  completed    Atomic Absorption Spectroscopy (AAS)  Lab 3
# 4          4001  completed                          NovaSeq X Plus  Lab 4
#
#     Requester Name      Booking Category Requested At  Start Time  \
# 0  KatrinaÊHildr¾d  Periodic Maintenance   2023/03/21  2023/10/16
# 1    DidemÊMallory  Periodic Maintenance   2023/03/21  2023/10/23
# 2    SamaraÊRegna  Periodic Maintenance   2023/03/21  2023/10/16
# 3       CyraÊLtfi  Periodic Maintenance   2023/03/21  2023/10/23
# 4  SrenÊEsmeralda  Periodic Maintenance   2023/03/21  2023/10/23
#
#    Duration (minutes)  Requester Group Name  Notes
# 0                 270                   NaN    NaN
# 1                 270                   NaN    NaN
# 2                 270                   NaN    NaN
# 3                 270                   NaN    NaN
# 4                 270                   NaN    NaN

# %%
#Reference file that we are analyzing
Lab_users_Path = Path(Lab_users_list)
Lab_users_RawData = pd.read_csv(Lab_users_list,encoding='latin-1')

#Clean up dataset to show only employees and department
del Lab_users_RawData['Lab User']
del Lab_users_RawData['Lab']
del Lab_users_RawData['Clustermarket Role']
#del Lab_users_RawData['Emaint training']
#del Lab_users_RawData['Emaint training completed']
#del Lab_users_RawData['Comments']

#Using unique() create lists of all the teams in R&D
Teams = []

#Create a for loop allowing the Teams list to capture unique values in column
for x in Lab_users_RawData['Team'].unique():
    Teams.append(x)

Teams
# Out:
# ['Translational',
#  'Development',
#  'Scientific Operations',
#  'Protein Development',
#  'Protein Research',
#  'PreAnalytics',
#  'Systems Integration',
#  'Genomics Research']

# %%
#Filter out the database to show employees by their departments
Translational_df = Lab_users_RawData[(Lab_users_RawData['Team']==Teams[0])]
Development_df = Lab_users_RawData[(Lab_users_RawData['Team']==Teams[1])]
SciOPs_df = Lab_users_RawData[(Lab_users_RawData['Team']==Teams[2])]
Protein_Development_df = Lab_users_RawData[(Lab_users_RawData['Team']==Teams[3])]
Protein_Research_df = Lab_users_RawData[(Lab_users_RawData['Team']==Teams[4])]
PreAnalytics_df = Lab_users_RawData[(Lab_users_RawData['Team']==Teams[5])]
Systems_Integration_df = Lab_users_RawData[(Lab_users_RawData['Team']==Teams[6])]
Genomics_Research_df = Lab_users_RawData[(Lab_users_RawData['Team']==Teams[7])]

#Create a list of departments to store employee name
Translational = []
nan = []
Development = []
PreAnalytics = []
Genomics_Research = []
SciOps = []
Protein_Development = [] 
Protein_Research = []
Systems_Integration= [] 
Automation = []

for x in Translational_df['Employee']:
    Translational.append(x)

for x in nan_df['Employee']:
    nan.append(x)

for x in Development_df['Employee']:
    Development.append(x)

for x in PreAnalytics_df['Employee']:
    PreAnalytics.append(x)

for x in Genomics_Research_df['Employee']:
    Genomics_Research.append(x)

for x in SciOPs_df['Employee']:
    SciOps.append(x)

for x in Protein_Development_df['Employee']:
    Protein_Development.append(x)

for x in Protein_Research_df['Employee']:
    Protein_Research.append(x)

for x in Systems_Integration_df['Employee']:
    Systems_Integration.append(x)


#Rename Requester with Department
Clustermarket_Data = Clustermarket_Data.rename(columns={"Requester Name":"Department"})

#Replace the Requester Name with DepartmentC
Clustermarket_Data['Department']=Clustermarket_Data['Department'].replace(Translational,'Translational')
Clustermarket_Data['Department']=Clustermarket_Data['Department'].replace(nan,'nan')
Clustermarket_Data['Department']=Clustermarket_Data['Department'].replace(Development,'Development')
Clustermarket_Data['Department']=Clustermarket_Data['Department'].replace(PreAnalytics,'PreAnalytics')
Clustermarket_Data['Department']=Clustermarket_Data['Department'].replace(Genomics_Research,'Genomics Research')
Clustermarket_Data['Department']=Clustermarket_Data['Department'].replace(SciOps,'SciOps')
Clustermarket_Data['Department']=Clustermarket_Data['Department'].replace(Protein_Development,'Protein Development')
Clustermarket_Data['Department']=Clustermarket_Data['Department'].replace(Protein_Research,'Protein Research')
Clustermarket_Data['Department']=Clustermarket_Data['Department'].replace(Systems_Integration,'Systems Integration')
Clustermarket_Data['Department']=Clustermarket_Data['Department'].replace(Automation,'Automation')

#New Cleaned Dataset
Clustermarket_Data.head()
# Out:
#    Equipment ID     Status                          Equipment Name   Room  \
# 0          1001  completed                   BioSafety Class II A2  Lab 1
# 1          1001  completed                   BioSafety Class II A2  Lab 1
# 2          2001  completed  AquaMate 8100 UV-Vis Spectrophotometer  Lab 2
# 3          3001  completed    Atomic Absorption Spectroscopy (AAS)  Lab 3
# 4          4001  completed                          NovaSeq X Plus  Lab 4
#
#       Department      Booking Category Requested At  Start Time  \
# 0  Translational  Periodic Maintenance   2023/03/21  2023/10/16
# 1  Translational  Periodic Maintenance   2023/03/21  2023/10/23
# 2  Translational  Periodic Maintenance   2023/03/21  2023/10/16
# 3  Translational  Periodic Maintenance   2023/03/21  2023/10/23
# 4  Translational  Periodic Maintenance   2023/03/21  2023/10/23
#
#    Duration (minutes)  Requester Group Name  Notes
# 0                 270                   NaN    NaN
# 1                 270                   NaN    NaN
# 2                 270                   NaN    NaN
# 3                 270                   NaN    NaN
# 4                 270                   NaN    NaN

# %% [markdown]
# <h1>Room Data Analysis</h1>

# %%
#General Room Overview
Clustermarket_Room_Data = Clustermarket_Data.groupby(['Room','Equipment Name']).count()
del Clustermarket_Room_Data['Equipment ID']
del Clustermarket_Room_Data['Department']
del Clustermarket_Room_Data['Booking Category']
del Clustermarket_Room_Data['Requested At']
del Clustermarket_Room_Data['Start Time']
del Clustermarket_Room_Data['Notes']
del Clustermarket_Room_Data['Duration (minutes)']
del Clustermarket_Room_Data['Requester Group Name']
Clustermarket_Room_Data
# Out:
#                                                      Status
# Room  Equipment Name
# Lab 1 AgilentÊ2100 BioanalyzerÊ                          13
#       BioSafety Class II A2                              26
#       CO2 Incubators                                     27
#       Hamilton Microlab NIMBUS                           35
#       Heratherm General Protocol Ovens                   26
#       Microlab STARV                                     23
#       Sorvallª ST 8 Small Benchtop Centrifuge            21
# Lab 2 Agilent BioTek 406 FX Washer Dispenser             30
#       AquaMate 8100 UV-Vis Spectrophotometer              7
#       BioTek Cytation C10 Confocal Imaging Reader        27
#       BravoBravo Automated Liquid Handling Platform      21
#       QIAquant Thermocycler                              21
#       Sorvall ST8 Bench Centrifuge                       65
#       TapeStation                                         5
# Lab 3 Atomic Absorption Spectroscopy (AAS)                4
#       Fragment Analyzer                                  18
#       Quincy Lab 10GC Gravity Convection Lab Oven        22
#       Sorvall ST8 Bench Centrifuge                       14
#       Triple Quadrupole LC/MS                            31
# Lab 4 Automata LINQ                                      25
#       DNBSEQ-G400 Genetic Sequencer                      17
#       NovaSeq X Plus                                      3
#       PTC Tempo Thermal Cycler                           32
#       QuantStudio Absolute Q Digital PCR System          32
#       Qubit 4 FluorometerÊ                               24
#       Sorvall ST8 Bench Centrifuge                       12

# %%
Clustermarket_Lab1 = Clustermarket_Data[(Clustermarket_Data["Room"]=="Lab 1")]
Clustermarket_Lab1_Equipment = Clustermarket_Lab1.groupby(['Equipment Name']).count().rename(columns={'Room':'# Bookings'})
del Clustermarket_Lab1_Equipment['Equipment ID']
del Clustermarket_Lab1_Equipment['Department']
del Clustermarket_Lab1_Equipment['Booking Category']
del Clustermarket_Lab1_Equipment['Requested At']
del Clustermarket_Lab1_Equipment['Start Time']
del Clustermarket_Lab1_Equipment['Notes']
del Clustermarket_Lab1_Equipment['Status']
del Clustermarket_Lab1_Equipment['Duration (minutes)']
del Clustermarket_Lab1_Equipment['Requester Group Name']

ax= Clustermarket_Lab1_Equipment.plot.bar(y="# Bookings",figsize=(10,10),color="m")
plt.ylabel('Frequency',fontsize=10)
plt.legend(loc='upper right')
ax.bar_label(ax.containers[0])

#Save image 
plt.savefig("Output/Lab1_Chart_1.png")

Clustermarket_Lab1_Equipment
# Out:
#                                          # Bookings
# Equipment Name
# AgilentÊ2100 BioanalyzerÊ                        13
# BioSafety Class II A2                            26
# CO2 Incubators                                   27
# Hamilton Microlab NIMBUS                         35
# Heratherm General Protocol Ovens                 26
# Microlab STARV                                   23
# Sorvallª ST 8 Small Benchtop Centrifuge          21

# %%
#Clustermarket_Lab1_Equipment
#Clustermarket_Lab1_Zero = Clustermarket_Lab1_Equipment[(Clustermarket_Lab1_Equipment["# Bookings"]==0)]
plt.figure(facecolor="w")
sns.heatmap(Clustermarket_Lab1_Equipment,
            annot=True,
            cmap=ListedColormap(['white']),
            linecolor="black",
            linewidth=1,
            square=True,
            cbar=False)

#Save image 
plt.savefig("Output/Lab1_Chart_2.png")

# %% [markdown]
# <h1>Equipment Status</h1>

# %%
Clustermarket_Lab1_Status = Clustermarket_Lab1.groupby(['Equipment Name','Booking Category']).count()
del Clustermarket_Lab1_Status["Notes"]
del Clustermarket_Lab1_Status["Equipment ID"]
del Clustermarket_Lab1_Status["Department"]
del Clustermarket_Lab1_Status["Requested At"]
del Clustermarket_Lab1_Status["Start Time"]
del Clustermarket_Lab1_Status["Duration (minutes)"]
del Clustermarket_Lab1_Status["Room"]
del Clustermarket_Lab1_Status["Requester Group Name"]
Clustermarket_Lab1_Status.rename(columns={"Status":"Lab1"})
Clustermarket_Lab1_Status = Clustermarket_Lab1_Status.pivot_table(index="Equipment Name",columns="Booking Category")
Clustermarket_Lab1_Status = Clustermarket_Lab1_Status.fillna(0)
Clustermarket_Lab1_Status
# Out:
#                                                       Status
# Booking Category                        Periodic Maintenance Unplanned   Use
# Equipment Name
# AgilentÊ2100 BioanalyzerÊ                                2.0       0.0  11.0
# BioSafety Class II A2                                   14.0       0.0  12.0
# CO2 Incubators                                           5.0      13.0   9.0
# Hamilton Microlab NIMBUS                                 6.0      19.0  10.0
# Heratherm General Protocol Ovens                         3.0       0.0  23.0
# Microlab STARV                                           0.0       2.0  21.0
# Sorvallª ST 8 Small Benchtop Centrifuge                  1.0       0.0  20.0

# %%
#Clustermarket_Lab1_Status.plot.bar(stacked=True)

ax = Clustermarket_Lab1_Status.plot(kind='bar', 
                    stacked=True, 
                    colormap='Set1', 
                    figsize=(10, 6))

ax.legend(["Periodic Maintenance","Unplanned","Use"],loc="upper left", ncol=2)
ax.set_xlabel("Booking Category")
ax.set_ylabel("Frequency")

#Labeling the bars in the graph
for c in ax.containers:
    ax.bar_label(c, fmt=lambda x: f'{x:.0f}' if x>0 else'', label_type='center',fontsize=9)


#Save image 
plt.savefig("Output/Lab1_Chart_3.png")

# %% [markdown]
# <h1>Department & Equipment Usage</h1>

# %%
#Listing Equipment in Lab1 Room
Lab1_equipment = Clustermarket_Lab1['Equipment Name'].unique()

Lab1_equipment
# Out:
# array(['BioSafety Class II A2', 'Hamilton Microlab NIMBUS',
#        'Microlab STARV', 'CO2 Incubators',
#        'Heratherm General Protocol Ovens',
#        'Sorvallª ST 8 Small Benchtop Centrifuge',
#        'AgilentÊ2100 BioanalyzerÊ'], dtype=object)

# %%
#Grouping Equipment Name and Department
Clustermarket_Lab1_User = Clustermarket_Lab1.groupby(['Equipment Name','Department']).count()

#Delete unnecessary columns
del Clustermarket_Lab1_User["Notes"]
del Clustermarket_Lab1_User["Equipment ID"]
del Clustermarket_Lab1_User["Booking Category"]
del Clustermarket_Lab1_User["Requested At"]
del Clustermarket_Lab1_User["Start Time"]
del Clustermarket_Lab1_User["Duration (minutes)"]
del Clustermarket_Lab1_User["Room"]
del Clustermarket_Lab1_User["Requester Group Name"]

#Remove name from column
Clustermarket_Lab1_User = Clustermarket_Lab1_User.rename(columns={"Status":" "})

#Create a pivot table for plotting
Clustermarket_Lab1_User = Clustermarket_Lab1_User.pivot_table(index="Equipment Name",columns="Department")

#Fill in NaN values with zero
Clustermarket_Lab1_User = Clustermarket_Lab1_User.fillna(0)

Clustermarket_Lab1_User
# Out:
#                                                                         \
# Department                              Genomics Research PreAnalytics
# Equipment Name
# AgilentÊ2100 BioanalyzerÊ                             0.0          1.0
# BioSafety Class II A2                                 4.0          0.0
# CO2 Incubators                                        6.0          3.0
# Hamilton Microlab NIMBUS                              1.0          2.0
# Heratherm General Protocol Ovens                      2.0          5.0
# Microlab STARV                                        7.0          6.0
# Sorvallª ST 8 Small Benchtop Centrifuge               6.0          3.0
#
#                                                                               \
# Department                              Protein Development Protein Research
# Equipment Name
# AgilentÊ2100 BioanalyzerÊ                               6.0              0.0
# BioSafety Class II A2                                   8.0              0.0
# CO2 Incubators                                          2.0              3.0
# Hamilton Microlab NIMBUS                                6.0              4.0
# Heratherm General Protocol Ovens                        3.0              3.0
# Microlab STARV                                          1.0              3.0
# Sorvallª ST 8 Small Benchtop Centrifuge                 0.0              1.0
#
#                                                                     \
# Department                              SciOps Systems Integration
# Equipment Name
# AgilentÊ2100 BioanalyzerÊ                  2.0                 0.0
# BioSafety Class II A2                      3.0                 0.0
# CO2 Incubators                             4.0                 2.0
# Hamilton Microlab NIMBUS                   2.0                 4.0
# Heratherm General Protocol Ovens           2.0                 1.0
# Microlab STARV                             0.0                 0.0
# Sorvallª ST 8 Small Benchtop Centrifuge    1.0                 0.0
#
#
# Department                              Translational   nan
# Equipment Name
# AgilentÊ2100 BioanalyzerÊ                         1.0   3.0
# BioSafety Class II A2                             4.0   7.0
# CO2 Incubators                                    3.0   4.0
# Hamilton Microlab NIMBUS                          4.0  12.0
# Heratherm General Protocol Ovens                  2.0   8.0
# Microlab STARV                                    4.0   2.0
# Sorvallª ST 8 Small Benchtop Centrifuge           6.0   4.0

# %%
#Creating the plot
ax = Clustermarket_Lab1_User.plot(kind='barh', 
                    stacked=True, 
                    colormap='Set2', 
                    figsize=(10, 6))

#Editing the legend
ax.legend(["Automation",
           "Genomics Research",
            "Protein Research",
            "SciOps",
            "Translational"
           ])

#Labeling the bars in the graph
for c in ax.containers:
    ax.bar_label(c, fmt=lambda x: f'{x:.0f}' if x>0 else'', label_type='center',fontsize=8)

#Save image 
plt.savefig("Output/Lab1_Chart_4.png")

# %% [markdown]
# <h1>Usage and Open Time Analysis</h1>

# %%
Clustermarket_Lab1_Time = pd.DataFrame(Clustermarket_Lab1,columns=[
    'Booking Category',
    'Equipment Name',
    'Duration (minutes)'
])

Clustermarket_Lab1_Time
# Out:
#          Booking Category             Equipment Name  Duration (minutes)
# 0    Periodic Maintenance      BioSafety Class II A2                 270
# 1    Periodic Maintenance      BioSafety Class II A2                 270
# 5    Periodic Maintenance      BioSafety Class II A2                 270
# 6    Periodic Maintenance      BioSafety Class II A2                 270
# 7    Periodic Maintenance      BioSafety Class II A2                  60
# ..                    ...                        ...                 ...
# 568                   Use  AgilentÊ2100 BioanalyzerÊ                 165
# 569                   Use  AgilentÊ2100 BioanalyzerÊ                 120
# 570                   Use  AgilentÊ2100 BioanalyzerÊ                 210
# 576                   Use  AgilentÊ2100 BioanalyzerÊ                 120
# 579                   Use  AgilentÊ2100 BioanalyzerÊ                  60
#
# [171 rows x 3 columns]

# %%
#Take into account maintenance, unplanned Booking category
Clustermarket_Lab1_Time_Percent = Clustermarket_Lab1_Time.copy()

#Group by room and usage
Clustermarket_Lab1_Time_Percent = Clustermarket_Lab1_Time_Percent.groupby(['Booking Category','Equipment Name']).sum()

#Creating a column that converts the minutes into hours
Clustermarket_Lab1_Time_Percent['Duration (hrs)'] = round((Clustermarket_Lab1_Time_Percent['Duration (minutes)']/60),1)

#Find the earliest and latest date in order to find time range
Lab1_min_time = Clustermarket_Lab1['Start Time'].min()
Lab1_max_time = Clustermarket_Lab1['Start Time'].max()

#Change type to datetime
Lab1_min_time_dt = dt.strptime(Lab1_min_time,'%Y/%m/%d')
Lab1_max_time_dt = dt.strptime(Lab1_max_time,'%Y/%m/%d')

#Subtract the earliest and latest times to find weeks
#Convert from datetime to integer first
time_wks = ((Lab1_max_time_dt - Lab1_min_time_dt).days)/7

#Delete column
del Clustermarket_Lab1_Time_Percent['Duration (minutes)']

#Transform groupby into pivot table
Clustermarket_Lab1_Time_Percent = Clustermarket_Lab1_Time_Percent.pivot_table(index=['Booking Category'], columns='Equipment Name',fill_value=0)

#Create new row to calculate Open hrs
Clustermarket_Lab1_Time_Percent.loc[len(Clustermarket_Lab1_Time_Percent)] = round((8*5*time_wks)-(Clustermarket_Lab1_Time_Percent.iloc[0:len(Clustermarket_Lab1_Time_Percent)].sum(numeric_only=True)),1)

#Rename New Row
Clustermarket_Lab1_Time_Percent = Clustermarket_Lab1_Time_Percent.rename({Clustermarket_Lab1_Time_Percent.index[-1]: 'Open'})

#Change the negative values to zero
Clustermarket_Lab1_Time_Percent[Clustermarket_Lab1_Time_Percent<0] = 0

#Turn into percentages
Clustermarket_Lab1_Time_Percent.iloc[0:len(Clustermarket_Lab1_Time_Percent)] = round(100*(Clustermarket_Lab1_Time_Percent.iloc[0:len(Clustermarket_Lab1_Time_Percent)]/(Clustermarket_Lab1_Time_Percent.iloc[0:len(Clustermarket_Lab1_Time_Percent)].sum())),1)

#Sort columns by Lab1betical order
Clustermarket_Lab1_Time_Percent = Clustermarket_Lab1_Time_Percent.sort_index(axis=1)

#Transpose for graphing
Clustermarket_Lab1_Time_Percent = Clustermarket_Lab1_Time_Percent.transpose()

Clustermarket_Lab1_Time_Percent
# Out:
# Booking Category                                        Periodic Maintenance  \
#                Equipment Name
# Duration (hrs) AgilentÊ2100 BioanalyzerÊ                                 2.4
#                BioSafety Class II A2                                    54.1
#                CO2 Incubators                                           14.3
#                Hamilton Microlab NIMBUS                                 33.2
#                Heratherm General Protocol Ovens                         13.5
#                Microlab STARV                                            0.0
#                Sorvallª ST 8 Small Benchtop Centrifuge                  25.4
#
# Booking Category                                        Unplanned   Use  Open
#                Equipment Name
# Duration (hrs) AgilentÊ2100 BioanalyzerÊ                      0.0  32.6  65.0
#                BioSafety Class II A2                          0.0  18.3  27.7
#                CO2 Incubators                                32.1  52.8   0.8
#                Hamilton Microlab NIMBUS                      42.9  23.9   0.0
#                Heratherm General Protocol Ovens               0.0  56.9  29.6
#                Microlab STARV                                 1.6  36.9  61.5
#                Sorvallª ST 8 Small Benchtop Centrifuge        0.0  40.5  34.0

# %%
#Formatting table to integer
#Clustermarket_Lab1_Time_Percent = Clustermarket_Lab1_Time_Percent.style.format('{:,.0f}')

ax = Clustermarket_Lab1_Time_Percent.plot.barh(stacked = True,
                                figsize=(20,15),
                                width=0.8, 
                                colormap='Set3',
                                fontsize=15,
                                align='center')

#Labeling x y axis
ax.set_ylabel('Equipment Name',fontsize=15)
ax.set_xlabel('',fontsize=15)
plt.title(f"Lab1 Usage Chart {Lab1_min_time} to {Lab1_max_time}",fontsize=20)

#Relabing y axis ticks
ax.set_yticklabels(Lab1_equipment)

#Renaming the Legend
ax.legend(fontsize=20)

#Labeling the bars in the graph
for c in ax.containers:
    ax.bar_label(c, fmt=lambda x: f'{x:.0f}%' if x>0 else'', label_type='center',fontsize=15)

#Save image 
plt.savefig("Output/Lab1_Chart_5.png")

# %% [markdown]
# <h1>Average Scheduling Time of Equipment Based on Room</h1>

# %%
Clustermarket_Booktime_Schedule = pd.DataFrame(Clustermarket_Data,columns=[
    'Department',
    'Room',
    'Requested At',
    'Start Time'])

#Convert dtype to Datetime
Clustermarket_Booktime_Schedule["Requested At"]= pd.to_datetime(Clustermarket_Booktime_Schedule["Requested At"], yearfirst=True, infer_datetime_format = True)
Clustermarket_Booktime_Schedule["Start Time"]= pd.to_datetime(Clustermarket_Booktime_Schedule["Start Time"], yearfirst=True, infer_datetime_format = True)

#Subtract and find dayes between Request and Booking
Clustermarket_Booktime_Schedule["Time Between Requested and Start Time"] = (Clustermarket_Booktime_Schedule["Start Time"]-Clustermarket_Booktime_Schedule["Requested At"]).dt.days

#Delete unnecessary columns
Clustermarket_Booktime_Schedule = Clustermarket_Booktime_Schedule.drop(['Requested At','Start Time'],axis=1)

#Change the negative values to zero
#Clustermarket_Booktime_Schedule.loc[Clustermarket_Booktime_Schedule["Time Between Requested and Start Time"]<0] = 0

Clustermarket_Booktime_Schedule
# Out:
# C:\Users\ljlle\AppData\Local\Temp\ipykernel_3428\3492137321.py:8: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   Clustermarket_Booktime_Schedule["Requested At"]= pd.to_datetime(Clustermarket_Booktime_Schedule["Requested At"], yearfirst=True, infer_datetime_format = True)
# C:\Users\ljlle\AppData\Local\Temp\ipykernel_3428\3492137321.py:9: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   Clustermarket_Booktime_Schedule["Start Time"]= pd.to_datetime(Clustermarket_Booktime_Schedule["Start Time"], yearfirst=True, infer_datetime_format = True)
#         Department   Room  Time Between Requested and Start Time
# 0    Translational  Lab 1                                    209
# 1    Translational  Lab 1                                    216
# 2    Translational  Lab 2                                    209
# 3    Translational  Lab 3                                    216
# 4    Translational  Lab 4                                    216
# ..             ...    ...                                    ...
# 576  Translational  Lab 1                                      1
# 577   PreAnalytics  Lab 2                                      0
# 578   PreAnalytics  Lab 3                                     -1
# 579   PreAnalytics  Lab 1                                      0
# 580   PreAnalytics  Lab 2                                      0
#
# [581 rows x 3 columns]

# %%
Rooms = Clustermarket_Data['Room'].unique()

Clustermarket_Booktime_Lab1 = Clustermarket_Booktime_Schedule[(Clustermarket_Booktime_Schedule["Room"]==Rooms[0])]

Clustermarket_Booktime_Room_Lab1 = Clustermarket_Booktime_Lab1.groupby(['Room','Department']).mean()

Clustermarket_Booktime_Room_Lab1 = Clustermarket_Booktime_Room_Lab1.pivot_table(index=['Room'], columns='Department')

Clustermarket_Booktime_Room_Lab1 = Clustermarket_Booktime_Room_Lab1.fillna(0)

ax = Clustermarket_Booktime_Room_Lab1.plot.bar()

#Labeling x y axis
ax.set_ylabel('Avg Time Between Request and Booking',fontsize=10)
ax.set_xlabel('',fontsize=15)
#plt.title(f"Lab1 Usage Chart {Lab1_min_time} to {Lab1_max_time}",fontsize=20)

#Renaming y axis ticks
#ax.set_yticklabels(Proteomics_equipment)

#Renaming the Legend
ax.legend(['Automation','Genomic Research','Protein Research','SciOps','Translational'],fontsize=10,loc='upper right')

#Labeling the bars in the graph
for c in ax.containers:
    ax.bar_label(c, fmt=lambda x: f'{x:.0f}' if x>0 else'', label_type='edge',fontsize=15)

#Save image 
plt.savefig("Output/Lab1_Chart_6.png")

# %% [markdown]
# <h1>Analysis of Equipment Usage in Workflow</h1>

# %%
#List out the equipment utilized in each workflow
#Randomize selection of equipment to demonstrate example

Genomics_equipment = Clustermarket_Data["Equipment Name"].sample(n=10)

Proteomics_equipment = Clustermarket_Data["Equipment Name"].sample(n=6)

# %%
#Filter out the df by equipment listed
Clustermarket_Genomics = Clustermarket_Data[Clustermarket_Data["Equipment Name"].isin(Genomics_equipment)]
Clustermarket_Proteomics = Clustermarket_Data[Clustermarket_Data["Equipment Name"].isin(Proteomics_equipment)]

#Delete unnecessary columns
Clustermarket_Genomics = Clustermarket_Genomics.drop(['Room','Equipment ID','Status','Requester Group Name','Notes'],axis=1)
Clustermarket_Proteomics = Clustermarket_Proteomics.drop(['Room','Equipment ID','Status','Requester Group Name','Notes'],axis=1)

Clustermarket_Genomics.head()
# Out:
#           Equipment Name     Department      Booking Category Requested At  \
# 0  BioSafety Class II A2  Translational  Periodic Maintenance   2023/03/21
# 1  BioSafety Class II A2  Translational  Periodic Maintenance   2023/03/21
# 5  BioSafety Class II A2  Translational  Periodic Maintenance   2023/03/21
# 6  BioSafety Class II A2            nan  Periodic Maintenance   2023/03/21
# 7  BioSafety Class II A2            nan  Periodic Maintenance   2023/03/22
#
#    Start Time  Duration (minutes)
# 0  2023/10/16                 270
# 1  2023/10/23                 270
# 5  2023/10/16                 270
# 6  2023/10/23                 270
# 7  2023/10/16                  60

# %%
#Take into account maintenance, unplanned Booking category
Clustermarket_Genomics_Time= Clustermarket_Genomics.copy()

#Group by room and usage
Clustermarket_Genomics_Time= Clustermarket_Genomics_Time.groupby(['Booking Category','Equipment Name']).sum(numeric_only=True)

Clustermarket_Genomics_Time
# Out:
#                                                                   Duration (minutes)
# Booking Category     Equipment Name
# Periodic Maintenance Agilent BioTek 406 FX Washer Dispenser                      270
#                      AgilentÊ2100 BioanalyzerÊ                                    90
#                      BioSafety Class II A2                                      2040
#                      BioTek Cytation C10 Confocal Imaging Reader                2175
#                      Fragment Analyzer                                          1140
#                      Sorvall ST8 Bench Centrifuge                              13485
#                      Triple Quadrupole LC/MS                                    1710
# Unplanned            Agilent BioTek 406 FX Washer Dispenser                     1800
#                      Sorvall ST8 Bench Centrifuge                                135
#                      Triple Quadrupole LC/MS                                    1815
# Use                  Agilent BioTek 406 FX Washer Dispenser                     5445
#                      AgilentÊ2100 BioanalyzerÊ                                  1230
#                      BioSafety Class II A2                                       690
#                      BioTek Cytation C10 Confocal Imaging Reader                3180
#                      DNBSEQ-G400 Genetic Sequencer                               510
#                      Fragment Analyzer                                           120
#                      Sorvall ST8 Bench Centrifuge                               7170
#                      Triple Quadrupole LC/MS                                    8760

# %%
#Creating a column that converts the minutes into hours
Clustermarket_Genomics_Time['Duration (hrs)'] = round((Clustermarket_Genomics_Time['Duration (minutes)']/60),1)

#Find the earliest and latest date in order to find time range
Genomics_min_time = Clustermarket_Genomics['Start Time'].min()
Genomics_max_time = Clustermarket_Genomics['Start Time'].max()

#Change type to datetime
Genomics_min_time_dt = dt.strptime(Genomics_min_time,'%Y/%m/%d')
Genomics_max_time_dt = dt.strptime(Genomics_max_time,'%Y/%m/%d')

#Subtract the earliest and latest times to find weeks
#Convert from datetime to integer first
time_wks_Genomics = ((Genomics_max_time_dt - Genomics_min_time_dt).days)/7

#Delete column
del Clustermarket_Genomics_Time['Duration (minutes)']

#Transform groupby into pivot table
Clustermarket_Genomics_Time= Clustermarket_Genomics_Time.pivot_table(index=['Booking Category'], columns='Equipment Name',fill_value=0)

#Create new row to calculate Open hrs
Clustermarket_Genomics_Time.loc[len(Clustermarket_Genomics_Time)] = round((8*5*time_wks_Genomics)-(Clustermarket_Genomics_Time.iloc[0:len(Clustermarket_Genomics_Time)].sum(numeric_only=True)),1)

#Rename New Row
Clustermarket_Genomics_Time= Clustermarket_Genomics_Time.rename({Clustermarket_Genomics_Time.index[-1]: 'Open'})

#Change the negative values to zero
Clustermarket_Genomics_Time[Clustermarket_Genomics_Time<0] = 0

#Turn into percentages
Clustermarket_Genomics_Time.iloc[0:len(Clustermarket_Genomics_Time)] = (round(100*(Clustermarket_Genomics_Time.iloc[0:len(Clustermarket_Genomics_Time)]/(Clustermarket_Genomics_Time.iloc[0:len(Clustermarket_Genomics_Time)].sum())),1)) 

#Sort columns by Lab1betical order
Clustermarket_Genomics_Time = Clustermarket_Genomics_Time.sort_index(axis=1)

#Transpose for graphing
Clustermarket_Genomics_Time= Clustermarket_Genomics_Time.transpose()

Clustermarket_Genomics_Time
# Out:
# Booking Category                                            Periodic Maintenance  \
#                Equipment Name
# Duration (hrs) Agilent BioTek 406 FX Washer Dispenser                        3.6
#                AgilentÊ2100 BioanalyzerÊ                                     2.4
#                BioSafety Class II A2                                        54.1
#                BioTek Cytation C10 Confocal Imaging Reader                  40.6
#                DNBSEQ-G400 Genetic Sequencer                                 0.0
#                Fragment Analyzer                                            30.2
#                Sorvall ST8 Bench Centrifuge                                 64.9
#                Triple Quadrupole LC/MS                                      13.9
#
# Booking Category                                            Unplanned   Use  \
#                Equipment Name
# Duration (hrs) Agilent BioTek 406 FX Washer Dispenser            23.9  72.5
#                AgilentÊ2100 BioanalyzerÊ                          0.0  32.6
#                BioSafety Class II A2                              0.0  18.3
#                BioTek Cytation C10 Confocal Imaging Reader        0.0  59.4
#                DNBSEQ-G400 Genetic Sequencer                      0.0  13.5
#                Fragment Analyzer                                  0.0   3.2
#                Sorvall ST8 Bench Centrifuge                       0.6  34.5
#                Triple Quadrupole LC/MS                           14.8  71.3
#
# Booking Category                                            Open
#                Equipment Name
# Duration (hrs) Agilent BioTek 406 FX Washer Dispenser        0.0
#                AgilentÊ2100 BioanalyzerÊ                    65.0
#                BioSafety Class II A2                        27.7
#                BioTek Cytation C10 Confocal Imaging Reader   0.0
#                DNBSEQ-G400 Genetic Sequencer                86.5
#                Fragment Analyzer                            66.6
#                Sorvall ST8 Bench Centrifuge                  0.0
#                Triple Quadrupole LC/MS                       0.0

# %%
#Renaming y axis ticks
#Formatting table to integer
#Clustermarket_Lab1_Time_Percent = Clustermarket_Lab1_Time_Percent.style.format('{:,.0f}')

ax = Clustermarket_Genomics_Time.plot.barh(stacked = True,
                                figsize=(20,15),
                                width=0.8, 
                                colormap='Set3',
                                fontsize=15,
                                align='center')

#Labeling x y axis
ax.set_ylabel('Equipment Name',fontsize=15)
ax.set_xlabel('',fontsize=15)
plt.title(f"Proteomics Workflow Equipment Usage Chart {Lab1_min_time} to {Lab1_max_time}",fontsize=20)

#Renaming y axis 
Genomics_equip_list = Genomics_equipment.unique()
ax.set_yticklabels(Genomics_equip_list)

#Renaming the Legend
ax.legend(fontsize=20,loc='center right')

#Labeling the bars in the graph
for c in ax.containers:
    ax.bar_label(c, fmt=lambda x: f'{x:.0f}%' if x>0 else'', label_type='center',fontsize=15)

#Save image 
plt.savefig("Output/Lab1_Chart_7.png")

# %%
#Take into account maintenance, unplanned Booking category
Clustermarket_Proteomics_Time= Clustermarket_Proteomics.copy()

#Group by room and usage
Clustermarket_Proteomics_Time= Clustermarket_Proteomics_Time.groupby(['Booking Category','Equipment Name']).sum(numeric_only=True)


#Creating a column that converts the minutes into hours
Clustermarket_Proteomics_Time['Duration (hrs)'] = round((Clustermarket_Proteomics_Time['Duration (minutes)']/60),1)

#Find the earliest and latest date in order to find time range
Proteomics_min_time = Clustermarket_Proteomics['Start Time'].min()
Proteomics_max_time = Clustermarket_Proteomics['Start Time'].max()

#Change type to datetime
Proteomics_min_time_dt = dt.strptime(Proteomics_min_time,'%Y/%m/%d')
Proteomics_max_time_dt = dt.strptime(Proteomics_max_time,'%Y/%m/%d')

#Subtract the earliest and latest times to find weeks
#Convert from datetime to integer first
time_wks_Proteomics = ((Proteomics_max_time_dt - Proteomics_min_time_dt).days)/7

#Delete column
del Clustermarket_Proteomics_Time['Duration (minutes)']

#Transform groupby into pivot table
Clustermarket_Proteomics_Time= Clustermarket_Proteomics_Time.pivot_table(index=['Booking Category'], columns='Equipment Name',fill_value=0)

#Create new row to calculate Open hrs
Clustermarket_Proteomics_Time.loc[len(Clustermarket_Proteomics_Time)] = round((8*5*time_wks_Proteomics)-(Clustermarket_Proteomics_Time.iloc[0:len(Clustermarket_Proteomics_Time)].sum(numeric_only=True)),1)

#Rename New Row
Clustermarket_Proteomics_Time= Clustermarket_Proteomics_Time.rename({Clustermarket_Proteomics_Time.index[-1]: 'Open'})

#Change the negative values to zero
Clustermarket_Proteomics_Time[Clustermarket_Proteomics_Time<0] = 0

#Turn into percentages
Clustermarket_Proteomics_Time.iloc[0:len(Clustermarket_Proteomics_Time)] = (round(100*(Clustermarket_Proteomics_Time.iloc[0:len(Clustermarket_Proteomics_Time)]/(Clustermarket_Proteomics_Time.iloc[0:len(Clustermarket_Proteomics_Time)].sum())),1)) 

#Sort columns by Lab1betical order
Clustermarket_Proteomics_Time = Clustermarket_Proteomics_Time.sort_index(axis=1)

#Transpose for graphing
Clustermarket_Proteomics_Time= Clustermarket_Proteomics_Time.transpose()

Clustermarket_Proteomics_Time
# Out:
# Booking Category                                 Periodic Maintenance  \
#                Equipment Name
# Duration (hrs) Automata LINQ                                     37.8
#                BioSafety Class II A2                             54.1
#                CO2 Incubators                                    14.3
#                DNBSEQ-G400 Genetic Sequencer                      0.0
#                Heratherm General Protocol Ovens                  13.5
#                Microlab STARV                                     0.0
#
# Booking Category                                 Unplanned   Use  Open
#                Equipment Name
# Duration (hrs) Automata LINQ                           0.0  62.2   0.0
#                BioSafety Class II A2                   0.0  18.3  27.7
#                CO2 Incubators                         32.1  52.8   0.8
#                DNBSEQ-G400 Genetic Sequencer           0.0  13.5  86.5
#                Heratherm General Protocol Ovens        0.0  56.9  29.6
#                Microlab STARV                          1.6  36.9  61.5

# %%
ax = Clustermarket_Proteomics_Time.plot.barh(stacked = True,
                                figsize=(20,15),
                                width=0.8, 
                                colormap='Set3',
                                fontsize=15,
                                align='center')

#Labeling x y axis
ax.set_ylabel('Equipment Name',fontsize=15)
ax.set_xlabel('',fontsize=15)
plt.title(f"Proteomics Workflow Equipment Usage Chart {Lab1_min_time} to {Lab1_max_time}",fontsize=20)

#Renaming y axis ticks 
Proteomics_equip_list = Proteomics_equipment.unique()
ax.set_yticklabels(Proteomics_equip_list)

#Renaming the Legend
ax.legend(fontsize=20,loc='center right')

#Labeling the bars in the graph
for c in ax.containers:
    ax.bar_label(c, fmt=lambda x: f'{x:.0f}%' if x>0 else'', label_type='center',fontsize=15)

#Save image 
plt.savefig("Output/Lab1_Chart_8.png")
